# %% [markdown]
# <a href="https://colab.research.google.com/github/Grishka3002/-/blob/main/lab3/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 3

# %% [markdown]
# ##Обработка пропущенных значений

# %% [markdown]
# Обработайте пропущенные значения:
#
#
# * Удалите пропущенные значения
# * Заполните при помощи медианы, среднего для числовых значений
# * Заполните при помощи моды для категориальных значений
# * Интерполируйте
# Выведите статистку после каждого метода и объясните

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)

# %%
import pandas as pd

df = pd.read_csv('/content/predictive_maintenance.csv')

# %%
#Удаление
df_filtered = df.dropna()
df_filtered.isna().sum()
# Out:
# UDI                        0
# Product ID                 0
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Target                     0
# Failure Type               0
# dtype: int64

# %%
#Заполнение при помощи медианы
median = df_filtered[column_name].median()
print (f"Median: {median}")
df.fillna(median)
# Out:
# Median: 40.1
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 0                       1551         42.8                0       0
# 1                       1408         46.3                3       0
# 2                       1498         49.4                5       0
# 3                       1433         39.5                7       0
# 4                       1408         40.0                9       0
# ...                      ...          ...              ...     ...
# 9995                    1604         29.5               14       0
# 9996                    1632         31.8               17       0
# 9997                    1645         33.4               22       0
# 9998                    1408         48.5               25       0
# 9999                    1500         40.2               30       0
#
#      Failure Type
# 0      No Failure
# 1      No Failure
# 2      No Failure
# 3      No Failure
# 4      No Failure
# ...           ...
# 9995   No Failure
# 9996   No Failure
# 9997   No Failure
# 9998   No Failure
# 9999   No Failure
#
# [10000 rows x 10 columns]

# %%
#Заполнение при помощи среднего
mean = df_filtered[column_name].mean()
print(f"Mean: {mean}")
df.fillna(mean)
# Out:
# Mean: 40.013288888888894
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 0                       1551         42.8                0       0
# 1                       1408         46.3                3       0
# 2                       1498         49.4                5       0
# 3                       1433         39.5                7       0
# 4                       1408         40.0                9       0
# ...                      ...          ...              ...     ...
# 9995                    1604         29.5               14       0
# 9996                    1632         31.8               17       0
# 9997                    1645         33.4               22       0
# 9998                    1408         48.5               25       0
# 9999                    1500         40.2               30       0
#
#      Failure Type
# 0      No Failure
# 1      No Failure
# 2      No Failure
# 3      No Failure
# 4      No Failure
# ...           ...
# 9995   No Failure
# 9996   No Failure
# 9997   No Failure
# 9998   No Failure
# 9999   No Failure
#
# [10000 rows x 10 columns]

# %%
#Заполнение при помощи моды
mode = df_filtered[column_name].mode()
print(f"Mode: {mode}")
df.fillna(mode)
# Out:
# Mode: 0    42.4
# Name: Torque [Nm], dtype: float64
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 0                       1551         42.8                0       0
# 1                       1408         46.3                3       0
# 2                       1498         49.4                5       0
# 3                       1433         39.5                7       0
# 4                       1408         40.0                9       0
# ...                      ...          ...              ...     ...
# 9995                    1604         29.5               14       0
# 9996                    1632         31.8               17       0
# 9997                    1645         33.4               22       0
# 9998                    1408         48.5               25       0
# 9999                    1500         40.2               30       0
#
#      Failure Type
# 0      No Failure
# 1      No Failure
# 2      No Failure
# 3      No Failure
# 4      No Failure
# ...           ...
# 9995   No Failure
# 9996   No Failure
# 9997   No Failure
# 9998   No Failure
# 9999   No Failure
#
# [10000 rows x 10 columns]

# %%
#Заполнение при помощи интерполяции
print(f"Before: {df.isna()[column_name].sum()}")
new_df = df.interpolate(method='index')
print(f"After: {new_df.isna()[column_name].sum()}")
new_df
# Out:
# Before: 1000
# After: 0
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 0                       1551         42.8                0       0
# 1                       1408         46.3                3       0
# 2                       1498         49.4                5       0
# 3                       1433         39.5                7       0
# 4                       1408         40.0                9       0
# ...                      ...          ...              ...     ...
# 9995                    1604         29.5               14       0
# 9996                    1632         31.8               17       0
# 9997                    1645         33.4               22       0
# 9998                    1408         48.5               25       0
# 9999                    1500         40.2               30       0
#
#      Failure Type
# 0      No Failure
# 1      No Failure
# 2      No Failure
# 3      No Failure
# 4      No Failure
# ...           ...
# 9995   No Failure
# 9996   No Failure
# 9997   No Failure
# 9998   No Failure
# 9999   No Failure
#
# [10000 rows x 10 columns]

# %% [markdown]
# **Объясните**

# %% [markdown]
# ##Поиск выбросов и аномалий

# %% [markdown]
# **Те, кто выполняет задания со * делают поиск выбросов с помощью написанного ранее класса**
#
# Найти выбросы по числовой переменной (использовать метод основанный на среднем и на межквартильном размахе). Объясните результат
#
# Вывести статистику с выбросами и без. Сравните и объясните результат

# %% [markdown]
# ##Дубликаты

# %% [markdown]
# Проверьте датафрейм на дубликаты и удалите их, если дублей нет - создайте.

# %%
#Проверка на дубли

True in list(df.duplicated())
# Out:
# False

# %%
# Создание дублей

new_df = pd.concat([new_df, new_df.iloc[3:10]])
True in list(df.duplicated())
# Out:
# False

# %%
#Удаление дублей

df = df.drop_duplicates()

if not True in list(df.duplicated()):
  print('Дубли удалены')
else:
  print('Дубли не удалены')

new_df
# Out:
# Дубли удалены
#     UDI        Product ID           Type  Air temperature [K]  \
# 0     1    (0, 6285)\t1.0    (0, 2)\t1.0                298.1
# 1     2     (0, 907)\t1.0    (0, 1)\t1.0                298.2
# 2     3     (0, 908)\t1.0    (0, 1)\t1.0                298.1
# 3     4     (0, 909)\t1.0    (0, 1)\t1.0                298.2
# 4     5     (0, 910)\t1.0    (0, 1)\t1.0                298.2
# ..  ...               ...            ...                  ...
# 6     7     (0, 911)\t1.0    (0, 1)\t1.0                298.1
# 7     8     (0, 912)\t1.0    (0, 1)\t1.0                298.1
# 8     9    (0, 6286)\t1.0    (0, 2)\t1.0                298.3
# 9    10    (0, 6287)\t1.0    (0, 2)\t1.0                298.5
# 10   11       (0, 0)\t1.0    (0, 0)\t1.0                298.4
#
#     Process temperature [K]  Rotational speed [rpm]  Torque [Nm]  \
# 0                     308.6                0.268395         42.8
# 1                     308.7                0.168185         46.3
# 2                     308.5                0.231254         49.4
# 3                     308.6                0.185704         39.5
# 4                     308.7                0.168185         40.0
# ..                      ...                     ...          ...
# 6                     308.6                0.273301         42.4
# 7                     308.6                0.251577         40.2
# 8                     308.7                0.349685         28.6
# 9                     309.0                0.401542         28.0
# 10                    308.9                0.430273         23.9
#
#     Tool wear [min]  Target Failure Type  Tool wear [min
# 0                 0       0   No Failure       -1.706109
# 1                 3       0   No Failure       -1.658858
# 2                 5       0   No Failure       -1.627358
# 3                 7       0   No Failure       -1.595858
# 4                 9       0   No Failure       -1.564357
# ..              ...     ...          ...             ...
# 6                14       0   No Failure       -1.485606
# 7                16       0   No Failure       -1.454106
# 8                18       0   No Failure       -1.422606
# 9                21       0   No Failure       -1.375355
# 10               24       0   No Failure       -1.328105
#
# [8959 rows x 11 columns]

# %% [markdown]
# ## Преобразование признаков

# %% [markdown]
# Масштабируйте числовые признаки через MinMaxScaler, StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Creating instances
min_max_scaler = MinMaxScaler()
standard_scaler = StandardScaler()

new_df[['Rotational speed [rpm]']] = min_max_scaler.fit_transform(new_df[['Rotational speed [rpm]']])
new_df[['Tool wear [min']] = standard_scaler.fit_transform(new_df[['Tool wear [min]']])

new_df[['Rotational speed [rpm]', 'Tool wear [min]']].describe()
# Out:
#        Rotational speed [rpm]  Tool wear [min]
# count             8945.000000      8945.000000
# mean                 0.257589       108.323197
# std                  0.117059        63.494929
# min                  0.000000         0.000000
# 25%                  0.178697        53.000000
# 50%                  0.235459       109.000000
# 75%                  0.309040       163.000000
# max                  1.000000       253.000000

# %% [markdown]
# Масштабируйте категориальные признаки через OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder

# Create an instance of OneHotEncoder
encoder = OneHotEncoder()

new_df[['Type']] = encoder.fit(new_df[['Type']]).transform(new_df[['Type']])
new_df[['Product ID']] = encoder.fit_transform(new_df[['Product ID']])

new_df[['Type', 'Product ID']]
# Out:
#                Type        Product ID
# 0       (0, 2)\t1.0    (0, 6285)\t1.0
# 1       (0, 1)\t1.0     (0, 907)\t1.0
# 2       (0, 1)\t1.0     (0, 908)\t1.0
# 3       (0, 1)\t1.0     (0, 909)\t1.0
# 4       (0, 1)\t1.0     (0, 910)\t1.0
# ...             ...               ...
# 9995    (0, 2)\t1.0    (0, 8942)\t1.0
# 9996    (0, 0)\t1.0     (0, 905)\t1.0
# 9997    (0, 2)\t1.0    (0, 8943)\t1.0
# 9998    (0, 0)\t1.0     (0, 906)\t1.0
# 9999    (0, 2)\t1.0    (0, 8944)\t1.0
#
# [8945 rows x 2 columns]

# %% [markdown]
# ##Задание для гениев*

# %% [markdown]
# Реализовать расчет корреляции Спирмана

# %%
#Функция по расчету тут

# %%
#Пример использования тут и объяснение принципа работы

# %% [markdown]
# ###Пример реализации

# %%
import pandas as pd
import numpy as np


def corr_pearson(column_1, column_2):
  cov = np.cov(column_1, column_2)
  return cov/(column_1.std() * column_2.std())

# %%
data = {
    'Рост': [170, 155, 180, 162, 175],
    'Вес': [65, 50, 75, 55, 70]
}
df = pd.DataFrame(data)
df
# Out:
#    Рост  Вес
# 0   170   65
# 1   155   50
# 2   180   75
# 3   162   55
# 4   175   70

# %%
corr_pearson(df["Рост"], df["Вес"])
# Out:
# array([[0.96593129, 0.99674864],
#        [0.99674864, 1.03527033]])
