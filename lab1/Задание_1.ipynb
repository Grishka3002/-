# %% [markdown]
# <a href="https://colab.research.google.com/github/Grishka3002/-/blob/main/lab1/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %% [markdown]
# ##Загрузка датасета
# В файле classification datasets расположены ссылки на датасеты. Выберите один в соответствии со своим вариантом, скачайте и прочитайте файл
#
# **Не забудьте загрузить нужные библиотеки**
#
# Например: pip3 install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("predictive_maintenance.csv")
df
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 0                       1551         42.8                0       0
# 1                       1408         46.3                3       0
# 2                       1498         49.4                5       0
# 3                       1433         39.5                7       0
# 4                       1408         40.0                9       0
# ...                      ...          ...              ...     ...
# 9995                    1604         29.5               14       0
# 9996                    1632         31.8               17       0
# 9997                    1645         33.4               22       0
# 9998                    1408         48.5               25       0
# 9999                    1500         40.2               30       0
#
#      Failure Type
# 0      No Failure
# 1      No Failure
# 2      No Failure
# 3      No Failure
# 4      No Failure
# ...           ...
# 9995   No Failure
# 9996   No Failure
# 9997   No Failure
# 9998   No Failure
# 9999   No Failure
#
# [10000 rows x 10 columns]

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
list(df.columns)
# Out:
# ['UDI',
#  'Product ID',
#  'Type',
#  'Air temperature [K]',
#  'Process temperature [K]',
#  'Rotational speed [rpm]',
#  'Torque [Nm]',
#  'Tool wear [min]',
#  'Target',
#  'Failure Type']

# %%
df.head(5)
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
df.tail(5)
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 9995                    1604         29.5               14       0
# 9996                    1632         31.8               17       0
# 9997                    1645         33.4               22       0
# 9998                    1408         48.5               25       0
# 9999                    1500         40.2               30       0
#
#      Failure Type
# 9995   No Failure
# 9996   No Failure
# 9997   No Failure
# 9998   No Failure
# 9999   No Failure

# %%
df.describe()
# Out:
#                UDI  Air temperature [K]  Process temperature [K]  \
# count  10000.00000         10000.000000             10000.000000
# mean    5000.50000           300.004930               310.005560
# std     2886.89568             2.000259                 1.483734
# min        1.00000           295.300000               305.700000
# 25%     2500.75000           298.300000               308.800000
# 50%     5000.50000           300.100000               310.100000
# 75%     7500.25000           301.500000               311.100000
# max    10000.00000           304.500000               313.800000
#
#        Rotational speed [rpm]   Torque [Nm]  Tool wear [min]        Target
# count            10000.000000  10000.000000     10000.000000  10000.000000
# mean              1538.776100     39.986910       107.951000      0.033900
# std                179.284096      9.968934        63.654147      0.180981
# min               1168.000000      3.800000         0.000000      0.000000
# 25%               1423.000000     33.200000        53.000000      0.000000
# 50%               1503.000000     40.100000       108.000000      0.000000
# 75%               1612.000000     46.800000       162.000000      0.000000
# max               2886.000000     76.600000       253.000000      1.000000

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %% [markdown]
# 1.   **Ответ 1.**
# 2.   **Ответ 2.**

# %%
df.mean(numeric_only=True)
# Out:
# UDI                        5000.50000
# Air temperature [K]         300.00493
# Process temperature [K]     310.00556
# Rotational speed [rpm]     1538.77610
# Torque [Nm]                  39.98691
# Tool wear [min]             107.95100
# Target                        0.03390
# dtype: float64

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
df.UDI = df.UDI.astype("int")
df.Type = df.Type.astype("category")
df.Target = df.Target.astype("float")

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
df[df['UDI']>9990]
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 9990   9991     L57170    L                298.8                    308.5
# 9991   9992     M24851    M                298.9                    308.4
# 9992   9993     L57172    L                298.8                    308.4
# 9993   9994     L57173    L                298.8                    308.4
# 9994   9995     L57174    L                298.8                    308.3
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 9990                    1527         36.2                3     0.0
# 9991                    1827         26.1                5     0.0
# 9992                    1484         39.2                8     0.0
# 9993                    1401         47.3               10     0.0
# 9994                    1634         27.9               12     0.0
# 9995                    1604         29.5               14     0.0
# 9996                    1632         31.8               17     0.0
# 9997                    1645         33.4               22     0.0
# 9998                    1408         48.5               25     0.0
# 9999                    1500         40.2               30     0.0
#
#      Failure Type
# 9990   No Failure
# 9991   No Failure
# 9992   No Failure
# 9993   No Failure
# 9994   No Failure
# 9995   No Failure
# 9996   No Failure
# 9997   No Failure
# 9998   No Failure
# 9999   No Failure

# %%
df[df["Torque [Nm]"]>70]
# Out:
#        UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 603    604     L47783    L                297.9                    309.8
# 880    881     M15740    M                295.8                    306.3
# 1324  1325     M16184    M                298.8                    310.1
# 3000  3001     H32414    H                300.5                    309.8
# 4936  4937     L52116    L                303.5                    312.4
# 5394  5395     M20254    M                302.8                    312.3
# 5615  5616     M20475    M                303.0                    312.2
# 6525  6526     L53705    L                301.1                    310.4
# 7569  7570     L54749    L                300.2                    311.0
# 7763  7764     L54943    L                300.4                    311.6
# 8582  8583     M23442    M                297.5                    308.1
# 9084  9085     L56264    L                297.2                    307.9
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 603                     1336         71.6               31     1.0
# 880                     1235         76.2               89     1.0
# 1324                    1243         74.5              194     1.0
# 3000                    1324         72.8              159     1.0
# 4936                    1284         70.6               94     1.0
# 5394                    1262         70.5              234     1.0
# 5615                    1257         71.3              122     1.0
# 6525                    1312         73.6               49     1.0
# 7569                    1255         71.8              149     1.0
# 7763                    1200         76.6                3     1.0
# 8582                    1334         72.0              151     1.0
# 9084                    1326         75.4              172     1.0
#
#        Failure Type
# 603   Power Failure
# 880   Power Failure
# 1324  Power Failure
# 3000  Power Failure
# 4936  Power Failure
# 5394  Power Failure
# 5615  Power Failure
# 6525  Power Failure
# 7569  Power Failure
# 7763  Power Failure
# 8582  Power Failure
# 9084  Power Failure

# %%
df[df["Tool wear [min]"]>250]
# Out:
#        UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 5400  5401     L52580    L                302.7                    312.4
# 5401  5402     M20261    M                302.6                    312.3
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 5400                    1477         46.3              251     1.0
# 5401                    1454         54.8              253     1.0
#
#             Failure Type
# 5400  Overstrain Failure
# 5401   Tool Wear Failure

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
df.groupby(['Type']).mean(numeric_only=True)
# Out:
#               UDI  Air temperature [K]  Process temperature [K]  \
# Type
# H     4981.918245           299.866999               309.925723
# L     4990.747667           300.015833               310.012300
# M     5026.242910           300.029263               310.018785
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]    Target
# Type
# H                1538.147557    39.838285       107.419741  0.020937
# L                1539.469167    39.996600       108.378833  0.039167
# M                1537.598932    40.017251       107.272272  0.027694

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
#Агрегация
